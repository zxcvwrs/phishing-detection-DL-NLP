# %% [markdown]
# ## E-mail parsing and preprocessing

# %% [markdown]
# #### Enron Corpotation ham dataset:
# - 16 545 ham mails

# %% [markdown]
# 0. Loading the dataset.

# %%
from collections import defaultdict
import os
import pandas as pd

enron_files_path = 'comparision_of_nlp_and_ml_methods_datasets\enron_ham_dataset'

res = defaultdict(list)
for file in os.listdir(enron_files_path):
    file_path = enron_files_path + '\\' + file
    with open(file_path, 'r') as f:
        res['file_name'].append(file)
        res['text'].append(f.read())

df_enron_unprocessed  = pd.DataFrame(res)

# %%
df_enron_unprocessed
# Out:
#                               file_name  \
# 0        0001.1999-12-10.farmer.ham.txt
# 1      0001.1999-12-10.kaminski.ham.txt
# 2          0001.2000-01-17.beck.ham.txt
# 3         0001.2000-06-06.lokay.ham.txt
# 4       0001.2001-02-07.kitchen.ham.txt
# ...                                 ...
# 16540     5990.2002-03-25.lokay.ham.txt
# 16541  5991.2002-02-07.williams.ham.txt
# 16542     5992.2002-03-25.lokay.ham.txt
# 16543  5995.2002-02-07.williams.ham.txt
# 16544     5996.2002-03-25.lokay.ham.txt
#
#                                                     text
# 0                Subject: christmas tree farm pictures\n
# 1                    Subject: re : rankings\nthank you .
# 2      Subject: leadership development pilot\nsally :...
# 3      Subject: key dates and impact of upcoming sap ...
# 4      Subject: key hr issues going forward\na ) year...
# ...                                                  ...
# 16540  Subject: fw : abandoned pipe ownership\nfyi , ...
# 16541  Subject: start date : 2 / 7 / 02 ; hourahead h...
# 16542  Subject: fw : tw question in amarillo\nfyi , k...
# 16543  Subject: start date : 2 / 6 / 02 ; hourahead h...
# 16544  Subject: fw : re ivanhoe e . s . d\nfyi , kim ...
#
# [16545 rows x 2 columns]

# %%
df_enron_unprocessed['text']
# Out:
# 0                  Subject: christmas tree farm pictures\n
# 1                      Subject: re : rankings\nthank you .
# 2        Subject: leadership development pilot\nsally :...
# 3        Subject: key dates and impact of upcoming sap ...
# 4        Subject: key hr issues going forward\na ) year...
#                                ...
# 16540    Subject: fw : abandoned pipe ownership\nfyi , ...
# 16541    Subject: start date : 2 / 7 / 02 ; hourahead h...
# 16542    Subject: fw : tw question in amarillo\nfyi , k...
# 16543    Subject: start date : 2 / 6 / 02 ; hourahead h...
# 16544    Subject: fw : re ivanhoe e . s . d\nfyi , kim ...
# Name: text, Length: 16545, dtype: object

# %%
df_enron_unprocessed.shape
# Out:
# (16545, 2)

# %%
df_enron_unprocessed.describe(include=object)
# Out:
#                              file_name  \
# count                            16545
# unique                           16545
# top     0001.1999-12-10.farmer.ham.txt
# freq                                 1
#
#                                                      text
# count                                               16545
# unique                                              15910
# top     Subject: calpine daily gas nomination\n>\nrick...
# freq                                                   20

# %%
df_enron_unprocessed.isnull().sum()
# Out:
# file_name    0
# text         0
# dtype: int64

# %%
pd.options.display.max_colwidth = 100

# %%
df_enron_unprocessed[df_enron_unprocessed['text'].duplicated()]
# Out:
#                               file_name  \
# 329       0109.2000-06-20.lokay.ham.txt
# 618      0208.2000-01-17.farmer.ham.txt
# 702    0236.2000-01-17.kaminski.ham.txt
# 729    0246.2000-01-18.kaminski.ham.txt
# 899    0302.2000-01-25.kaminski.ham.txt
# ...                                 ...
# 16408  5810.2001-05-07.kaminski.ham.txt
# 16419  5817.2001-05-07.kaminski.ham.txt
# 16422  5819.2001-05-07.kaminski.ham.txt
# 16460  5850.2001-05-22.kaminski.ham.txt
# 16528     5972.2002-03-25.lokay.ham.txt
#
#                                                                                                       text
# 329    Subject: cera says average natural gas price for 2000 will be $ 3 . 67 at henry\nhub\n- - - - - ...
# 618    Subject: global risk management operations\nrecognizing enron  , s increasing worldwide presenc...
# 702    Subject: global risk management operations\nrecognizing enron  , s increasing worldwide presenc...
# 729    Subject: re : global risk management operations\nrick ,\ni read your memo regarding global risk ...
# 899    Subject: organizational announcement\nenron is off to a fantastic start this year as we continue...
# ...                                                                                                    ...
# 16408  Subject: re : enron visit - - thanks\nlarry ,\ni was thinking about the potential applications o...
# 16419  Subject: re : schedule and more . .\njinbaek ,\nmay 30 sounds good . i shall inform our hr depar...
# 16422  Subject: schedule and more . .\ndr . kaminski ,\ni think i ' ll be able to start work from the l...
# 16460  Subject: california update 5 / 22 / 01\nplease treat as confidential\na source had a meeting tod...
# 16528  Subject: new power executive - - free sample issue\nwe welcome you to download a free\ntrial iss...
#
# [635 rows x 2 columns]

# %%
df_enron_unprocessed = df_enron_unprocessed[~df_enron_unprocessed['text'].duplicated()]

# %%
df_enron_unprocessed
# Out:
#                               file_name  \
# 0        0001.1999-12-10.farmer.ham.txt
# 1      0001.1999-12-10.kaminski.ham.txt
# 2          0001.2000-01-17.beck.ham.txt
# 3         0001.2000-06-06.lokay.ham.txt
# 4       0001.2001-02-07.kitchen.ham.txt
# ...                                 ...
# 16540     5990.2002-03-25.lokay.ham.txt
# 16541  5991.2002-02-07.williams.ham.txt
# 16542     5992.2002-03-25.lokay.ham.txt
# 16543  5995.2002-02-07.williams.ham.txt
# 16544     5996.2002-03-25.lokay.ham.txt
#
#                                                                                                       text
# 0                                                                  Subject: christmas tree farm pictures\n
# 1                                                                      Subject: re : rankings\nthank you .
# 2      Subject: leadership development pilot\nsally :\nwhat timing , ask and you shall receive . as per...
# 3      Subject: key dates and impact of upcoming sap implementation\nover the next few weeks , project ...
# 4      Subject: key hr issues going forward\na ) year end reviews - report needs generating like mid - ...
# ...                                                                                                    ...
# 16540  Subject: fw : abandoned pipe ownership\nfyi , kim .\n- - - - - original message - - - - -\nfrom ...
# 16541  Subject: start date : 2 / 7 / 02 ; hourahead hour : 1 ;\nstart date : 2 / 7 / 02 ; hourahead hou...
# 16542  Subject: fw : tw question in amarillo\nfyi , kim .\n- - - - - original message - - - - -\nfrom :...
# 16543  Subject: start date : 2 / 6 / 02 ; hourahead hour : 24 ;\nstart date : 2 / 6 / 02 ; hourahead ho...
# 16544  Subject: fw : re ivanhoe e . s . d\nfyi , kim .\n- - - - - original message - - - - -\nfrom : fr...
#
# [15910 rows x 2 columns]

# %%
df_enron_unprocessed.reset_index(inplace=True)

# %%
df_enron_unprocessed.drop({'index'}, axis=1, inplace=True)
# Out:
# C:\Users\rwole\AppData\Local\Temp\ipykernel_4976\2049744523.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_enron_unprocessed.drop({'index'}, axis=1, inplace=True)

# %% [markdown]
# 1. Extracting the body text.

# %%
string_ = 'Subject: re : rankings\nthank you .'
string_.split('\n')[1]
# Out:
# 'thank you .'

# %%
def extract_body_enron(mail):
    extracted_body = mail.split('\n')[1]
    return extracted_body

# %% [markdown]
# 2. Lowercasing all characters
# 3. Removing nonalphanumeric characters, special characters, punctuation marks, whitespaces caused by removal, stopwords, HTML elements.
# 4. Replacing hyperlinks with fixed strings
# 5. Tokenization based on white spaces

# %%
from bs4 import BeautifulSoup
def _remove_html_tags(body):
    try:
        soup = BeautifulSoup(body, 'html.parser')
        return soup.get_text()
    except Exception as e:
        print(f'Exception occured at: {e} with {body}')
        return "to_manual_extraction"

# %%
test1 = '<<sc<script>script>alert(1&lt)<</sc</script>/script>'
print(_remove_html_tags(test1))
# Out:
# <script>alert(1<)</script>

# %%
from nltk.corpus import stopwords
def _tokenize(body, stopwords=stopwords):
    body = body.split(" ")
    body = [token for token in body if not token in stopwords.words('english')]
    return body

# %%
len(stopwords.words('english'))
# Out:
# 179

# %%
import re
import cleantext

def prepare_body_mail(body, tokenize_flag=True):
    body = body.lower()
    body = _remove_html_tags(body)
    try:
        body = cleantext.replace_urls(body, replace_with="fixedstringurl")
        body = re.sub(r'\S+@\S+', 'fixedstringemails', body)
        body = re.sub(r"[^a-zA-Z0-9\s]", '', body) 
        body = " ".join(body.split())
    except Exception as e:
        print(f'Exception occured at: {e} with {body}')
        return 'to_manual_extraction'
    if tokenize_flag:
        body = _tokenize(body)
    return body

# %%
prepare_body_mail('This is some https://google.com text with a &lt; symbol</p>')
# Out:
# ['fixedstringurl', 'text', 'symbol']

# %%
prepare_body_mail("I will meet ~ you _ _ = + { '` at 9 :) ! ? &$*!)ZX****")
# Out:
# ['meet', '9', 'zx']

# %%
prepare_body_mail("""<td>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nb=
sp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
		&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&=
nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
		&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&=
nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
		&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&=
nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</td>""")
# Out:
# ['nb', 'sp', 'nbsp', 'nbsp', 'nbsp']

# %%
prepare_body_mail(df_enron_unprocessed['text'][100])
# Out:
# ['subject',
#  'gas',
#  'daily',
#  'options',
#  'revaluation',
#  'inform',
#  'rolling',
#  'changes',
#  'gas',
#  'daily',
#  'option',
#  'pricing',
#  'model',
#  'currently',
#  'system',
#  'properly',
#  'pricing',
#  'index',
#  'puts',
#  'calls',
#  'locations',
#  'gas',
#  'daily',
#  'index',
#  'premiums',
#  'discounts',
#  'puts',
#  'calls',
#  'priced',
#  'level',
#  'matter',
#  'index',
#  'change',
#  'result',
#  'raising',
#  'call',
#  'values',
#  'lowering',
#  'put',
#  'values',
#  'locations',
#  'index',
#  'premiums',
#  'opposite',
#  'locations',
#  'index',
#  'discounts',
#  'addition',
#  'index',
#  'minus',
#  'option',
#  'deals',
#  'index',
#  '1',
#  '00',
#  'puts',
#  'currently',
#  'incorrectly',
#  'priced',
#  'flat',
#  'index',
#  'option',
#  'index',
#  '1',
#  '00',
#  'put',
#  'priced',
#  'flat',
#  'index',
#  'put',
#  'accurately',
#  'priced',
#  'reflect',
#  'difference',
#  'strikes',
#  'questions',
#  'call',
#  '3',
#  '6731',
#  'larry']

# %%
prepare_body_mail(df_enron_unprocessed['text'][2000])
# Out:
# ['subject',
#  'meeting',
#  'friday',
#  'storage',
#  'mark',
#  'heard',
#  'lot',
#  'things',
#  'discuss',
#  'possibly',
#  'john',
#  'bloomer',
#  'richard',
#  'reichardt',
#  'ebs',
#  'research',
#  'role',
#  'supporting',
#  'storage',
#  'market',
#  'development',
#  'origination',
#  'trading',
#  'perspective',
#  'groups',
#  'talking',
#  'storage',
#  'involvement',
#  'correct',
#  'suggest',
#  'shalesh',
#  'ganjoo',
#  'lead',
#  'analyst',
#  'effort',
#  'addition',
#  'effort',
#  'group',
#  'presently',
#  'supporting',
#  'jean',
#  'mrha',
#  'pricing',
#  'standardization',
#  'traded',
#  'storage',
#  'maret',
#  'stinson',
#  'gibner',
#  'directly',
#  'supervising',
#  'effort',
#  'shalesh',
#  'referal',
#  'david',
#  'cox',
#  'david',
#  'discovered',
#  'speaking',
#  'engagements',
#  'shalesh',
#  'talked',
#  'david',
#  'traded',
#  'storage',
#  'market',
#  'development',
#  'time',
#  'october',
#  'david',
#  'refered',
#  'shalesh',
#  'enron',
#  'research',
#  'group',
#  'hired',
#  'shalesh',
#  'general',
#  'analyst',
#  'position',
#  'pulled',
#  'aspect',
#  'storage',
#  'effort',
#  'currently',
#  'point',
#  'person',
#  'stinson',
#  'supervising',
#  'effort',
#  'supporting',
#  'jean',
#  'mrha',
#  'subject',
#  'knop',
#  'aproached',
#  'shalesh',
#  'request',
#  'support',
#  'shalesh',
#  'sorting',
#  'role',
#  'regard',
#  'discussion',
#  'today',
#  'david',
#  'coordinate',
#  'storage',
#  'effort',
#  'perspective',
#  'modeling',
#  'market',
#  'assessment',
#  'suggest',
#  'shalesh',
#  'effort',
#  'parties',
#  'involved',
#  'benefit',
#  'collective',
#  'effort',
#  'central',
#  'source',
#  'based',
#  'david',
#  'assessment',
#  'shalesh',
#  'capabilities',
#  'suggest',
#  'commercial',
#  'heads',
#  'shalesh',
#  'creative',
#  'understanding',
#  'market',
#  'analytical',
#  'capabilities',
#  'data',
#  'gathering',
#  'simple',
#  'research',
#  'effort',
#  'add',
#  'staff',
#  'request',
#  'respond',
#  'mail',
#  'comments',
#  'sounds',
#  'aplan',
#  'support',
#  'effort',
#  'efficiently',
#  'scalable',
#  'manner',
#  'kind',
#  'ravi',
#  'bit',
#  'ebs',
#  'research',
#  'group',
#  'john',
#  'bloomer',
#  'richard',
#  'reichardt',
#  'aware',
#  'role',
#  'stinston',
#  'gibner',
#  'role',
#  'ebs',
#  'lead',
#  'team',
#  'quantitative',
#  'professionals',
#  'group',
#  'calling',
#  'ebs',
#  'research',
#  'group',
#  'reports',
#  'stinson',
#  'gibner',
#  'vp',
#  'vince',
#  'kaminski',
#  'md',
#  'head',
#  'enron',
#  'research',
#  'stinson',
#  'vince',
#  'original',
#  'founders',
#  'enron',
#  'corp',
#  'research',
#  'charged',
#  'model',
#  'development',
#  'efforts',
#  'support',
#  'enron',
#  'energy',
#  'trading',
#  'enron',
#  'business',
#  'enron',
#  'research',
#  'involved',
#  'aspects',
#  'enron',
#  'buinesses',
#  'ees',
#  'international',
#  'corporate',
#  'affairs',
#  '133',
#  'accounting',
#  'product',
#  'derivatives',
#  'development',
#  'ebs',
#  'research',
#  'serveral',
#  'professionals',
#  'supporting',
#  'kevin',
#  'howard',
#  'cfo',
#  'office',
#  'john',
#  'griebling',
#  'tom',
#  'gros',
#  'jean',
#  'mrha',
#  'david',
#  'cox',
#  'boris',
#  'room',
#  'area',
#  'focus',
#  'jean',
#  'mrha',
#  'trading',
#  'john',
#  'griebling',
#  'optical',
#  'network',
#  'design',
#  'optimization',
#  'play',
#  'key',
#  'role',
#  'john',
#  'griebling',
#  'forward',
#  'network',
#  'design',
#  'implementation',
#  'responsiblity',
#  'provide',
#  'traffic',
#  'engineering',
#  'analysis',
#  'modeling',
#  'effort',
#  'forwarded',
#  'ravi',
#  'thuraisingham',
#  'enron',
#  'communications',
#  '03',
#  '08',
#  '00',
#  '09',
#  '31',
#  'shalesh',
#  'ganjoo',
#  'ect',
#  '03',
#  '07',
#  '00',
#  '08',
#  '01',
#  'pm',
#  'mark',
#  'palmer',
#  'enron',
#  'communications',
#  'enron',
#  'communications',
#  'cc',
#  'ravi',
#  'thuraisingham',
#  'enron',
#  'communications',
#  'enron',
#  'communications',
#  'enron',
#  'subject',
#  'meeting',
#  'friday',
#  'storage',
#  'dear',
#  'mark',
#  'forward',
#  'presenting',
#  'competitive',
#  'analysis',
#  'storage',
#  'market',
#  'friday',
#  'ravi',
#  'thurasingham',
#  'calling',
#  'find',
#  'research',
#  'group',
#  'assist',
#  'group',
#  'information',
#  'meet',
#  'sincerely',
#  'shalesh',
#  'ganjoo']

# %% [markdown]
# ### Jose Nazario's phishing dataset

# %% [markdown]
# #### 0. Load dataset and extract body

# %%
jose_file_path= 'comparision_of_nlp_and_ml_methods_datasets\jose_phishing_dataset'

# %%
import email
import pandas as pd
from collections import defaultdict
import os

res = defaultdict(list)

for file in os.listdir(jose_file_path):
    file_path = jose_file_path + '\\' + file

    with open(file_path, 'rb') as f:
        text = f.read()

    messages = text.split(b'From ')

    df_jose_unprocessed = pd.DataFrame(columns=['body'])

    for message in messages:
        msg = email.message_from_bytes(message)
        body = None
        if msg.is_multipart(): # if e-mail contains multipart
            for part in msg.walk():
                if part.get_content_type() == 'text/plain':
                    body = part.get_payload(decode=True)
        else:
            body = msg.get_payload(decode=True) # case if single part message, extract payload
        if body:
            body = body.decode(errors='ignore') # ignore if decoding errors
            lines = body.split('\n')
            for i, line in enumerate(lines):
                if not line:
                    body = '\n'.join(lines[i+1:])
                    break
            if body:
                #df_jose_unprocessed = df_jose_unprocessed.append({'body': body}, ignore_index=True)
                res['body'].append(body)

df_jose_unprocessed = pd.DataFrame(res)

# %%
df_jose_unprocessed.head(20)
# Out:
#                                                  body
# 0   This text is part of the internal format of yo...
# 1   <HTML><BODY><P>\n<TABLE style="PADDING-BOTTOM:...
# 2   <HTML><BODY><P>\n<TABLE style="PADDING-BOTTOM:...
# 3   You will not see this in a MIME-aware mail rea...
# 4   You will not see this in a MIME-aware mail rea...
# 5   <a href="http://mx1.corrierefranco.it/images/l...
# 6   This is a multi-part message in MIME format.\n...
# 7   This is a multi-part message in MIME format.\n...
# 8   You will not see this in a MIME-aware mail rea...
# 9   PCFET0NUWVBFIGh0bWwgUFVCTElDICItLy9XM0MvL0RURC...
# 10  You will not see this in a MIME-aware mail rea...
# 11  You will not see this in a MIME-aware mail rea...
# 12  <img alt=3D"" src=3D"http://image.autowini.com...
# 13  You will not see this in a MIME-aware mail rea...
# 14  --_000_A05060B2FAF93545934CA5A098EA6DCB9E1DE61...
# 15  PCFET0NUWVBFIEhUTUwgUFVCTElDICItLy9XM0MvL0RURC...
# 16  You will not see this in a MIME-aware mail rea...
# 17  ------=_Part_362015_226506545.1423233831479\nC...
# 18  PCFET0NUWVBFIGh0bWwgUFVCTElDICItLy9XM0MvL0RURC...
# 19  This is a multi-part message in MIME format.\n...

# %%
df_jose_unprocessed[df_jose_unprocessed['body'].str.contains('Content-Type')]
# Out:
#                                                    body
# 3     You will not see this in a MIME-aware mail rea...
# 4     You will not see this in a MIME-aware mail rea...
# 6     This is a multi-part message in MIME format.\n...
# 7     This is a multi-part message in MIME format.\n...
# 8     You will not see this in a MIME-aware mail rea...
# ...                                                 ...
# 2010  jose@monkey.org Thu Jul 23 00:41:02 2020 +0000...
# 2012  jose@monkey.org Wed Nov 25 19:18:34 2020 +0000...
# 2014  jose@monkey.org Fri Mar 26 09:56:35 2021 +0000...
# 2016  jose@monkey.org Sat Aug 21 22:29:30 2021 +0000...
# 2018  jose@monkey.org Wed Dec 29 16:09:05 2021 +0000...
#
# [1436 rows x 1 columns]

# %%
strings_to_remove = ('Content-Type', 'Content-Transfer-Encoding', 'MIME-Version', 'Subject', 'From', 'To', 'Date', 'Message-ID', 'X-Mailer', 
    'X-MimeOLE', 'X-Priority', 'X-MSMail-Priority', 'X-Originating-IP', 'X-Spam', 'X-Spam-Status',
    'text/plain', 'You will not see this in a MIME-aware mail reader.', 'jose@monkey.org', '--===============',
    "This is a multi-part message in MIME format.", 'Return-Path', 'charset=', 'Delivered-', '--', 'Content-Description: Mail message body =',
    'X-FDA:', 'Received:', 'Content-type:', 'Content-Description:', 'This is a MIME message. If you are reading this text, you may want to consider changing to a mail reader or gateway that understands how to properly handle MIME multipart messages.'
    '------=_', 'This is a MIME encoded message', 'This is a multipart message in MIME format.', 'This message is in MIME format.', 'Content-Disposition:',
    'format=', 'boundary=', 'X-HE-Tag: ', 'X-Filterd-Recvd-Size: ', 'by imf02.b.hostedemail.com', '(Postfix)', 'jose@login.monkey.org', 'monkey.org', 
    'X-Forwarded-For: Authentication-Results: ', 'Message-Id: ', 'X-Probable-Spam: ', 'X-Scanned-By: MIMEDefang 2', 'X-Scanned-By', 'X-Keywords:', 
    'X-UID: ', 'DKIM-Signature:', 'c=relaxed/relaxed')

def remove_or_extract(mail):
    for string_to_remove in strings_to_remove:
        while string_to_remove in mail:
            index = mail.find(string_to_remove)
            end_index = mail.find('\n', index)
            if end_index == -1: # if not found \n it searches for \r
                end_index = mail.find('\r', index)
            if end_index != -1:
                mail = mail[:index] + mail[end_index:]
            else:
                mail = mail.replace(string_to_remove, "")
                break
    return mail

#print(remove_or_extract(df_jose_unprocessed['body'][0]))

# %%
test = 'X-HE-Tag: field65_1d996008eda40X-Filterd-Recvd-Size: 167813	by imf29.b.hostedemail.com (Postfix) with ESMTP	for <: E-payment Transfer Notification '
print(remove_or_extract(test))
# Out:
# field65_1d996008eda40167813	by imf29.b.hostedemail.com  with ESMTP	for <: E-payment Transfer Notification

# %%
test = 'Message-Id: <201505070107.t4714pSl019206@rx-csb2.smtp.ucla.edu>X-Probable-Spam: noX-Scanned-By: MIMEDefang 2'
print(remove_or_extract(test))
# Out:
# <201505070107.t4714pSl019206@rx-csb2.smtp.ucla.edu>no

# %%
#df_jose_unprocessed['body'][4]

# %%
#df_jose_unprocessed['body'][6]

# %%
#remove_or_extract(df_jose_unprocessed['body'][6])

# %%
#remove_or_extract(df_jose_unprocessed['body'][4])

# %%
df_jose_unprocessed['body_preprocessed'] = df_jose_unprocessed['body'].apply(remove_or_extract)

# %%
pd.options.display.max_columns = None

# %%
#df_jose_unprocessed['body_preprocessed'][0]

# %%
#df_jose_unprocessed['body_preprocessed'][1500]

# %%
df_jose_unprocessed[df_jose_unprocessed['body_preprocessed'].duplicated()]
# Out:
#                                                    body  \
# 2     <HTML><BODY><P>\n<TABLE style="PADDING-BOTTOM:...
# 38    --===============1237846325258372660==\nConten...
# 40    <HTML><head>\n<title>E-mail Spam and Fraudulen...
# 56    ------=_Part_181894881_1753846385.142854573218...
# 79    --a45ec92d8870fad56eb731e5548883\nContent-Type...
# ...                                                 ...
# 1979  jose@monkey.org Mon Jan  2 07:56:20 2017 +0000...
# 1988            Administrator\r\nThread-Topic: Message
# 1991            Administrator\r\nThread-Topic: Message
# 1994            Administrator\r\nThread-Topic: Message
# 2005                                        to Friday,
#
#                                       body_preprocessed
# 2     <HTML><BODY><P>\n<TABLE style="PADDING-BOTTOM:...
# 38    \n\n\n\n\n( https://email-edg.paypal.com/r/EKD...
# 40    <HTML><head>\n<title>E-mail Spam and Fraudulen...
# 56    \n\n\n\n\n\nDear Valued User,\n Please note th...
# 79    \n\n\n\n\n \n \n \n \n \n \n \n \n \n \n \n \n...
# ...                                                 ...
# 1979  \n\n\n\n\n\n\n\n\tby imf27.b.hostedemail.com \...
# 1988              Administrator\r\nThread-pic: Message
# 1991              Administrator\r\nThread-pic: Message
# 1994              Administrator\r\nThread-pic: Message
# 2005                                        to Friday,
#
# [150 rows x 2 columns]

# %% [markdown]
# #### 1. Drop duplicates

# %%
df_jose_unprocessed = df_jose_unprocessed[~df_jose_unprocessed['body_preprocessed'].duplicated()]
df_jose_unprocessed.reset_index(inplace=True, drop=True)

# %%
df_jose_unprocessed
# Out:
#                                                    body  \
# 0     This text is part of the internal format of yo...
# 1     <HTML><BODY><P>\n<TABLE style="PADDING-BOTTOM:...
# 2     You will not see this in a MIME-aware mail rea...
# 3     You will not see this in a MIME-aware mail rea...
# 4     <a href="http://mx1.corrierefranco.it/images/l...
# ...                                                 ...
# 1864  jose@monkey.org Fri Mar 26 09:56:35 2021 +0000...
# 1865  jose@monkey.org Fri Mar 26 16:59:14 2021 +0000...
# 1866  jose@monkey.org Sat Aug 21 22:29:30 2021 +0000...
# 1867  monkey.org Server Admin<br></span></td></tr></...
# 1868  jose@monkey.org Wed Dec 29 16:09:05 2021 +0000...
#
#                                       body_preprocessed
# 0     This text is part of the internal format of yo...
# 1     <HTML><BODY><P>\n<TABLE style="PADDING-BOTTOM:...
# 2     \n\n\n\n\n\n\n\n   \t =\n\n   Dear Customer,\n...
# 3     \n\n\n\n\n\n\n\n   \t =\n\n   Dear Customer,\n...
# 4     <a href="http://mx1.corrierefranco.it/images/l...
# ...                                                 ...
# 1864  \n\n\n\n\n\tby imf22.b.hostedemail.com \n\tfor...
# 1865  \n\n\n\n\n\tby imf18.b.hostedemail.com \n\tfor...
# 1866  \n\n\n\n\n\tby imf20.b.hostedemail.com \n\tfor...
# 1867  \n\r\n\r\n<div style=3D"width: 700px; color: r...
# 1868  \n\n\n\n\n\tby imf06.b.hostedemail.com \n\tfor...
#
# [1869 rows x 2 columns]

# %%
df_jose_unprocessed['body_preprocessed'].isna().sum()
# Out:
# 0

# %% [markdown]
# #### 2. Try to decode using base64 and check types of elements

# %%
def _check_element(body):
    if not isinstance(body, str):
        return True
    else:
        return False

# %%
df_jose_unprocessed[df_jose_unprocessed['body_preprocessed'].apply(_check_element)]
# Out:
# Empty DataFrame
# Columns: [body, body_preprocessed]
# Index: []

# %%
df_jose_unprocessed[df_jose_unprocessed['body_preprocessed'] == '']
# Out:
# Empty DataFrame
# Columns: [body, body_preprocessed]
# Index: []

# %%
df_jose_unprocessed['body_preprocessed_cleaned_body'] = df_jose_unprocessed['body_preprocessed'].apply(prepare_body_mail)
# Out:
# c:\Users\rwole\AppData\Local\Programs\Python\Python310\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Exception occured at: expected name token at '<![=\nendif]\n<!\ncolor' with <!doctype html public "-//w3c//dtd xhtml 1.0 transitional //en" "http://www=
# =2ew3.org/tr/xhtml1/dtd/xhtml1-transitional.dtd">
#
# <html xmlns=3d"http://www.w3.org/1999/xhtml" xmlns:o=3d"urn:schemas-microso=
# ft-com:office:office" xmlns:v=3d"urn:schemas-microsoft-com:vml">
# <head>
# <!
# inch>96</o:pixelsperinch></o:officedocumentsettings></xml><![endif]
# <meta content=3d"text/html;
# <meta content=3d"width=3ddevice-width" name=3d"viewport"/>
# <!
# <meta content=3d"ie=3dedge" http-equiv=3d"x-ua-compatible"/>
# <!
# <title></title>
# <!
# <!
# <style type=3d"text/css">
# 		body {
# 			margin: 0;
# 			padding: 0;
# 		}
#
# 		table,
# 		td,
# 		tr {
# 			vertical-align: top;
# 			border-collapse: collapse;
# 		}
#
# 		* {
# 			line-height: inherit;
# 		}
#
# 		a[x-apple-data-detectors=3dtrue] {
# 			color: inherit !important;
# 			text-decoration: none !important;
# 		}
# 	</style>
# <style id=3d"media-query" type=3d"text/css">
# 		@media (max-width: 520px) {
#
# 			.block-grid,
# 			.col {
# 				min-width: 320px !important;
# 				max-width: 100% !important;
# 				display: block !important;
# 			}
#
# 			.block-grid {
# 				width: 100% !important;
# 			}
#
# 			.col {
# 				width: 100% !important;
# 			}
#
# 			.col>div {
# 				margin: 0 auto;
# 			}
#
# 			img.fullwidth,
# 			img.fullwidthonmobile {
# 				max-width: 100% !important;
# 			}
#
# 			.no-stack .col {
# 				min-width: 0 !important;
# 				display: table-cell !important;
# 			}
#
# 			.no-stack.two-up .col {
# 				width: 50% !important;
# 			}
#
# 			.no-stack .col.num4 {
# 				width: 33% !important;
# 			}
#
# 			.no-stack .col.num8 {
# 				width: 66% !important;
# 			}
#
# 			.no-stack .col.num4 {
# 				width: 33% !important;
# 			}
#
# 			.no-stack .col.num3 {
# 				width: 25% !important;
# 			}
#
# 			.no-stack .col.num6 {
# 				width: 50% !important;
# 			}
#
# 			.no-stack .col.num9 {
# 				width: 75% !important;
# 			}
#
# 			.video-block {
# 				max-width: none !important;
# 			}
#
# 			.mobile_hide {
# 				min-height: 0px;
# 				max-height: 0px;
# 				max-width: 0px;
# 				display: none;
# 				overflow: hidden;
# 				font-size: 0px;
# 			}
#
# 			.desktop_hide {
# 				display: block !important;
# 				max-height: none !important;
# 			}
# 		}
# 	</style>
# </head>
# <body class=3d"clean-body" style=3d"margin: 0; padding: 0; -webkit-text-siz=
# e-adjust: 100%; background-color: #ffffff;">
# <!
# <table bgcolor=3d"#ffffff" cellpadding=3d"0" cellspacing=3d"0" class=3d"nl-=
# container" role=3d"presentation" style=3d"table-layout: fixed; vertical-ali=
# gn: top; min-width: 320px; margin: 0 auto; border-spacing: 0; border-collap=
# se: collapse; mso-table-lspace: 0pt; mso-table-rspace: 0pt; background-colo=
# r: #ffffff; width: 100%;" valign=3d"top" width=3d"100%">
# <tbody>
# <tr style=3d"vertical-align: top;" valign=3d"top">
# <td style=3d"word-break: break-word; vertical-align: top;" valign=3d"top">
# <!
# 0" border=3d"0"><tr><td align=3d"center" style=3d"background-color:#ffffff"=
# ><![endif]
# <div style=3d"background-color:#ffffff;">
# <div class=3d"block-grid mixed-two-up" style=3d"margin: 0 auto; min-width: =
# 320px; max-width: 500px; overflow-wrap: break-word; word-wrap: break-word; =
# word-break: break-word; background-color: #ff0000;">
# <div style=3d"border-collapse: collapse;display: table;width: 100%;backgrou=
# nd-color:#ff0000;">
# <!
# 0" border=3d"0" style=3d"background-color:#ffffff;"><tr><td align=3d"center=
# "><table cellpadding=3d"0" cellspacing=3d"0" border=3d"0" style=3d"width:50=
# 0px"><tr class=3d"layout-full-width" style=3d"background-color:#ff0000"><![=
# endif]
# <!
# color:#ff0000;width:166px; border-top: 0px solid transparent; border-left: =
# 0px solid transparent; border-bottom: 0px solid transparent; border-right: =
# 0px solid transparent;" valign=3d"top"><table width=3d"100%" cellpadding=3d=
# "0" cellspacing=3d"0" border=3d"0"><tr><td style=3d"padding-right: 0px; pad=
# ding-left: 0px; padding-top:5px; padding-bottom:5px;"><![endif]
# <div class=3d"col num4" style=3d"display: table-cell; vertical-align: top; =
# max-width: 320px; min-width: 164px; width: 166px;">
# <div style=3d"width:100% !important;">
# <!
# <div style=3d"border-top:0px solid transparent; border-left:0px solid trans=
# parent; border-bottom:0px solid transparent; border-right:0px solid transpa=
# rent; padding-top:5px; padding-bottom:5px; padding-right: 0px; padding-left=
# : 0px;">
# <!
# <!
# er=3d"0"><tr><td style=3d"padding-right: 10px; padding-left: 10px; padding-=
# top: 10px; padding-bottom: 10px; font-family: arial, sans-serif"><![endif]-=
# ->
# <div style=3d"color:#555555;font-family:arial, 'helvetica neue', helvetica,=
#  sans-serif;line-height:1.2;padding-top:10px;padding-right:10px;padding-bot=
# tom:10px;padding-left:10px;">
# <p style=3d"font-size: 18px; line-height: 1.2; color: #555555; font-family:=
#  arial, 'helvetica neue', helvetica, sans-serif; mso-line-height-alt: 22px;=
#  margin: 0;"><span style=3d"font-size: 18px; color: #ffffff;">wells fargo</=
# span></p>
# </div>
# <!
# <!
# </div>
# <!
# </div>
# </div>
# <!
# <!
# ound-color:#ff0000;width:333px; border-top: 0px solid transparent; border-l=
# eft: 0px solid transparent; border-bottom: 0px solid transparent; border-ri=
# ght: 0px solid transparent;" valign=3d"top"><table width=3d"100%" cellpaddi=
# ng=3d"0" cellspacing=3d"0" border=3d"0"><tr><td style=3d"padding-right: 0px=
# ; padding-left: 0px; padding-top:5px; padding-bottom:5px;"><![endif]
# <div class=3d"col num8" style=3d"display: table-cell; vertical-align: top; =
# min-width: 320px; max-width: 328px; width: 333px;">
# <div style=3d"width:100% !important;">
# <!
# <div style=3d"border-top:0px solid transparent; border-left:0px solid trans=
# parent; border-bottom:0px solid transparent; border-right:0px solid transpa=
# rent; padding-top:5px; padding-bottom:5px; padding-right: 0px; padding-left=
# : 0px;">
# <!
# <!
# er=3d"0"><tr><td style=3d"padding-right: 10px; padding-left: 10px; padding-=
# top: 10px; padding-bottom: 10px; font-family: georgia, 'times new roman', s=
# erif"><![endif]
# <div style=3d"color:#555555;font-family:georgia, times, 'times new roman', =
# serif;line-height:1.2;padding-top:10px;padding-right:10px;padding-bottom:10=
# px;padding-left:10px;">
# <p style=3d"font-size: 14px; line-height: 1.2; color: #555555; font-family:=
#  georgia, times, 'times new roman', serif; mso-line-height-alt: 17px; margi=
# n: 0;"><span style=3d"font-size: 14px;"><strong><span style=3d"color: #ffff=
# ff; font-size: 14px;">online banking</span></strong></span></p>
# </div>
# <!
# <!
# </div>
# <!
# </div>
# </div>
# <!
# <!
# </div>
# </div>
# </div>
# <div style=3d"background-color:#ffffff;">
# <div class=3d"block-grid" style=3d"margin: 0 auto; min-width: 320px; max-wi=
# dth: 500px; overflow-wrap: break-word; word-wrap: break-word; word-break: b=
# reak-word; background-color: transparent;">
# <div style=3d"border-collapse: collapse;display: table;width: 100%;backgrou=
# nd-color:transparent;">
# <!
# 0" border=3d"0" style=3d"background-color:#ffffff;"><tr><td align=3d"center=
# "><table cellpadding=3d"0" cellspacing=3d"0" border=3d"0" style=3d"width:50=
# 0px"><tr class=3d"layout-full-width" style=3d"background-color:transparent"=
# ><![endif]
# <!
# color:transparent;width:500px; border-top: 0px solid transparent; border-le=
# ft: 0px solid transparent; border-bottom: 0px solid transparent; border-rig=
# ht: 0px solid transparent;" valign=3d"top"><table width=3d"100%" cellpaddin=
# g=3d"0" cellspacing=3d"0" border=3d"0"><tr><td style=3d"padding-right: 0px;=
#  padding-left: 0px; padding-top:0px; padding-bottom:0px;"><![endif]
# <div class=3d"col num12" style=3d"min-width: 320px; max-width: 500px; displ=
# ay: table-cell; vertical-align: top; width: 500px;">
# <div style=3d"width:100% !important;">
# <!
# <div style=3d"border-top:0px solid transparent; border-left:0px solid trans=
# parent; border-bottom:0px solid transparent; border-right:0px solid transpa=
# rent; padding-top:0px; padding-bottom:0px; padding-right: 0px; padding-left=
# : 0px;">
# <!
# <table border=3d"0" cellpadding=3d"0" cellspacing=3d"0" class=3d"divider" r=
# ole=3d"presentation" style=3d"table-layout: fixed; vertical-align: top; bor=
# der-spacing: 0; border-collapse: collapse; mso-table-lspace: 0pt; mso-table=
# -rspace: 0pt; min-width: 100%; -ms-text-size-adjust: 100%; -webkit-text-siz=
# e-adjust: 100%;" valign=3d"top" width=3d"100%">
# <tbody>
# <tr style=3d"vertical-align: top;" valign=3d"top">
# <td class=3d"divider_inner" style=3d"word-break: break-word; vertical-align=
# : top; min-width: 100%; -ms-text-size-adjust: 100%; -webkit-text-size-adjus=
# t: 100%; padding-top: 0px; padding-right: 0px; padding-bottom: 0px; padding=
# -left: 0px;" valign=3d"top">
# <table align=3d"center" border=3d"0" cellpadding=3d"0" cellspacing=3d"0" cl=
# ass=3d"divider_content" height=3d"0" role=3d"presentation" style=3d"table-l=
# ayout: fixed; vertical-align: top; border-spacing: 0; border-collapse: coll=
# apse; mso-table-lspace: 0pt; mso-table-rspace: 0pt; border-top: 6px solid #=
# f8d500; height: 0px; width: 100%;" valign=3d"top" width=3d"100%">
# <tbody>
# <tr style=3d"vertical-align: top;" valign=3d"top">
# <td height=3d"0" style=3d"word-break: break-word; vertical-align: top; -ms-=
# text-size-adjust: 100%; -webkit-text-size-adjust: 100%;" valign=3d"top"><sp=
# an></span></td>
# </tr>
# </tbody>
# </table>
# </td>
# </tr>
# </tbody>
# </table>
# <!
# </div>
# <!
# </div>
# </div>
# <!
# <!
# </div>
# </div>
# </div>
# <div style=3d"background-color:transparent;">
# <div class=3d"block-grid" style=3d"margin: 0 auto; min-width: 320px; max-wi=
# dth: 500px; overflow-wrap: break-word; word-wrap: break-word; word-break: b=
# reak-word; background-color: transparent;">
# <div style=3d"border-collapse: collapse;display: table;width: 100%;backgrou=
# nd-color:transparent;">
# <!
# 0" border=3d"0" style=3d"background-color:transparent;"><tr><td align=3d"ce=
# nter"><table cellpadding=3d"0" cellspacing=3d"0" border=3d"0" style=3d"widt=
# h:500px"><tr class=3d"layout-full-width" style=3d"background-color:transpar=
# ent"><![endif]
# <!
# color:transparent;width:500px; border-top: 0px solid transparent; border-le=
# ft: 0px solid transparent; border-bottom: 0px solid transparent; border-rig=
# ht: 0px solid transparent;" valign=3d"top"><table width=3d"100%" cellpaddin=
# g=3d"0" cellspacing=3d"0" border=3d"0"><tr><td style=3d"padding-right: 0px;=
#  padding-left: 0px; padding-top:5px; padding-bottom:5px;"><![endif]
# <div class=3d"col num12" style=3d"min-width: 320px; max-width: 500px; displ=
# ay: table-cell; vertical-align: top; width: 500px;">
# <div style=3d"width:100% !important;">
# <!
# <div style=3d"border-top:0px solid transparent; border-left:0px solid trans=
# parent; border-bottom:0px solid transparent; border-right:0px solid transpa=
# rent; padding-top:5px; padding-bottom:5px; padding-right: 0px; padding-left=
# : 0px;">
# <!
# <!
# er=3d"0"><tr><td style=3d"padding-right: 10px; padding-left: 10px; padding-=
# top: 10px; padding-bottom: 10px; font-family: arial, sans-serif"><![endif]-=
# ->
# <div style=3d"color:#555555;font-family:arial, 'helvetica neue', helvetica,=
#  sans-serif;line-height:1.2;padding-top:10px;padding-right:10px;padding-bot=
# tom:10px;padding-left:10px;">
# <div style=3d"font-family: arial, 'helvetica neue', helvetica, sans-serif; =
# font-size: 12px; line-height: 1.2; color: #555555; mso-line-height-alt: 14p=
# x;">
# <p style=3d"font-size: 14px; line-height: 1.2; mso-line-height-alt: 17px; m=
# argin: 0;"><span style=3d"color: #000000; font-size: 14px;"><span style=3d"=
# font-size: 16px;"><strong>account locked notification</strong></span>.</spa=
# n><br/><br/><br/><span style=3d"color: #000000; font-size: 14px;">we had to=
#  lock your wells fargo online banking access temporary to protect your secu=
# rity.
# an><br/><br/><br/><span style=3d"color: #000000; font-size: 14px;">
# ete this process <span style=3d"color: #ff0000; font-size: 14px;"><span sty=
# le=3d"font-size: 14px;"><a href=3d"https://wesfado.info/wells/fargo" rel=3d=
# "noopener" style=3d"text-decoration: underline; color: #ff0000;" target=3d"=
# _blank">click here</a></span>.</span></span><br/><br/><br/><br/><span style=
# =3d"color: #000000; font-size: 14px;">please make sure you enter same infor=
# mation as in the account, changing information on the account with other in=
# formation can result on permanent locking and it request new procedure for =
# unlocking.</span><br/><br/><span style=3d"color: #000000; font-size: 14px;"=
# > </span><br/><span style=3d"color: #000000; font-size: 14px;">thank you!<b=
# r/>wells fargo online.<br/></span></p>
# </div>
# </div>
# <!
# <!
# </div>
# <!
# </div>
# </div>
# <!
# <!
# </div>
# </div>
# </div>
# <div style=3d"background-color:transparent;">
# <div class=3d"block-grid" style=3d"margin: 0 auto; min-width: 320px; max-wi=
# dth: 500px; overflow-wrap: break-word; word-wrap: break-word; word-break: b=
# reak-word; background-color: #eed5b4;">
# <div style=3d"border-collapse: collapse;display: table;width: 100%;backgrou=
# nd-color:#eed5b4;">
# <!
# 0" border=3d"0" style=3d"background-color:transparent;"><tr><td align=3d"ce=
# nter"><table cellpadding=3d"0" cellspacing=3d"0" border=3d"0" style=3d"widt=
# h:500px"><tr class=3d"layout-full-width" style=3d"background-color:#eed5b4"=
# ><![endif]
# <!
# color:#eed5b4;width:500px; border-top: 0px solid transparent; border-left: =
# 0px solid transparent; border-bottom: 0px solid transparent; border-right: =
# 0px solid transparent;" valign=3d"top"><table width=3d"100%" cellpadding=3d=
# "0" cellspacing=3d"0" border=3d"0"><tr><td style=3d"padding-right: 0px; pad=
# ding-left: 0px; padding-top:5px; padding-bottom:5px;"><![endif]
# <div class=3d"col num12" style=3d"min-width: 320px; max-width: 500px; displ=
# ay: table-cell; vertical-align: top; width: 500px;">
# <div style=3d"width:100% !important;">
# <!
# <div style=3d"border-top:0px solid transparent; border-left:0px solid trans=
# parent; border-bottom:0px solid transparent; border-right:0px solid transpa=
# rent; padding-top:5px; padding-bottom:5px; padding-right: 0px; padding-left=
# : 0px;">
# <!
# <!
# er=3d"0"><tr><td style=3d"padding-right: 10px; padding-left: 10px; padding-=
# top: 10px; padding-bottom: 10px; font-family: arial, sans-serif"><![endif]-=
# ->
# <div style=3d"color:#555555;font-family:arial, 'helvetica neue', helvetica,=
#  sans-serif;line-height:1.2;padding-top:10px;padding-right:10px;padding-bot=
# tom:10px;padding-left:10px;">
# <div style=3d"font-family: arial, 'helvetica neue', helvetica, sans-serif; =
# font-size: 12px; line-height: 1.2; color: #555555; mso-line-height-alt: 14p=
# x;">
# <p style=3d"font-size: 9px; line-height: 1.2; text-align: center; mso-line-=
# height-alt: 11px; margin: 0;"><span style=3d"font-size: 9px;">important not=
# ice regarding use of cookies: by continuing to use this site, you agree to =
# our use of cookies as described in our digital privacy and cookies policy .=
# </span><br/><br/><span style=3d"font-size: 9px;">investment products and se=
# rvices are offered through wells fargo advisors. wells fargo advisors is a =
# trade name used by wells fargo clearing services, llc (wfcs) and wells farg=
# o advisors financial network, llc, members sipc, separate registered broker=
# -dealers and non-bank affiliates of wells fargo &amp; company. wellstrade=
# =ae and intuitive investor=ae accounts are offered through wfcs.</span><br/=
# ><br/></p>
# <p style=3d"font-size: 12px; line-height: 1.2; text-align: center; mso-line=
# -height-alt: 14px; margin: 0;">deposit products offered by wells fargo bank=
# , n.a. member fdic.<br/> equal housing lender</p>
# <p style=3d"font-size: 12px; line-height: 1.2; text-align: center; mso-line=
# -height-alt: 14px; margin: 0;">=a9 1999 - 2019 wells fargo. all rights rese=
# rved. nmlsr id 399801</p>
# </div>
# </div>
# <!
# <!
# </div>
# <!
# </div>
# </div>
# <!
# <!
# </div>
# </div>
# </div>
# <!
# </td>
# </tr>
# </tbody>
# </table>
# <!
# </body>
# </html>
#
#
# Exception occured at: expected name token at '<![=\nendif]\n<!\ncolor' with <!doctype html public "-//w3c//dtd xhtml 1.0 transitional //en" "http://www=
# =2ew3.org/tr/xhtml1/dtd/xhtml1-transitional.dtd">
#
# <html xmlns=3d"http://www.w3.org/1999/xhtml" xmlns:o=3d"urn:schemas-microso=
# ft-com:office:office" xmlns:v=3d"urn:schemas-microsoft-com:vml">
# <head>
# <!
# inch>96</o:pixelsperinch></o:officedocumentsettings></xml><![endif]
# <meta content=3d"text/html;
# <meta content=3d"width=3ddevice-width" name=3d"viewport"/>
# <!
# <meta content=3d"ie=3dedge" http-equiv=3d"x-ua-compatible"/>
# <!
# <title></title>
# <!
# <!
# <style type=3d"text/css">
# 		body {
# 			margin: 0;
# 			padding: 0;
# 		}
#
# 		table,
# 		td,
# 		tr {
# 			vertical-align: top;
# 			border-collapse: collapse;
# 		}
#
# 		* {
# 			line-height: inherit;
# 		}
#
# 		a[x-apple-data-detectors=3dtrue] {
# 			color: inherit !important;
# 			text-decoration: none !important;
# 		}
# 	</style>
# <style id=3d"media-query" type=3d"text/css">
# 		@media (max-width: 520px) {
#
# 			.block-grid,
# 			.col {
# 				min-width: 320px !important;
# 				max-width: 100% !important;
# 				display: block !important;
# 			}
#
# 			.block-grid {
# 				width: 100% !important;
# 			}
#
# 			.col {
# 				width: 100% !important;
# 			}
#
# 			.col>div {
# 				margin: 0 auto;
# 			}
#
# 			img.fullwidth,
# 			img.fullwidthonmobile {
# 				max-width: 100% !important;
# 			}
#
# 			.no-stack .col {
# 				min-width: 0 !important;
# 				display: table-cell !important;
# 			}
#
# 			.no-stack.two-up .col {
# 				width: 50% !important;
# 			}
#
# 			.no-stack .col.num4 {
# 				width: 33% !important;
# 			}
#
# 			.no-stack .col.num8 {
# 				width: 66% !important;
# 			}
#
# 			.no-stack .col.num4 {
# 				width: 33% !important;
# 			}
#
# 			.no-stack .col.num3 {
# 				width: 25% !important;
# 			}
#
# 			.no-stack .col.num6 {
# 				width: 50% !important;
# 			}
#
# 			.no-stack .col.num9 {
# 				width: 75% !important;
# 			}
#
# 			.video-block {
# 				max-width: none !important;
# 			}
#
# 			.mobile_hide {
# 				min-height: 0px;
# 				max-height: 0px;
# 				max-width: 0px;
# 				display: none;
# 				overflow: hidden;
# 				font-size: 0px;
# 			}
#
# 			.desktop_hide {
# 				display: block !important;
# 				max-height: none !important;
# 			}
# 		}
# 	</style>
# </head>
# <body class=3d"clean-body" style=3d"margin: 0; padding: 0; -webkit-text-siz=
# e-adjust: 100%; background-color: #ffffff;">
# <!
# <table bgcolor=3d"#ffffff" cellpadding=3d"0" cellspacing=3d"0" class=3d"nl-=
# container" role=3d"presentation" style=3d"table-layout: fixed; vertical-ali=
# gn: top; min-width: 320px; margin: 0 auto; border-spacing: 0; border-collap=
# se: collapse; mso-table-lspace: 0pt; mso-table-rspace: 0pt; background-colo=
# r: #ffffff; width: 100%;" valign=3d"top" width=3d"100%">
# <tbody>
# <tr style=3d"vertical-align: top;" valign=3d"top">
# <td style=3d"word-break: break-word; vertical-align: top;" valign=3d"top">
# <!
# 0" border=3d"0"><tr><td align=3d"center" style=3d"background-color:#ffffff"=
# ><![endif]
# <div style=3d"background-color:#ffffff;">
# <div class=3d"block-grid mixed-two-up" style=3d"margin: 0 auto; min-width: =
# 320px; max-width: 500px; overflow-wrap: break-word; word-wrap: break-word; =
# word-break: break-word; background-color: #ff0000;">
# <div style=3d"border-collapse: collapse;display: table;width: 100%;backgrou=
# nd-color:#ff0000;">
# <!
# 0" border=3d"0" style=3d"background-color:#ffffff;"><tr><td align=3d"center=
# "><table cellpadding=3d"0" cellspacing=3d"0" border=3d"0" style=3d"width:50=
# 0px"><tr class=3d"layout-full-width" style=3d"background-color:#ff0000"><![=
# endif]
# <!
# color:#ff0000;width:166px; border-top: 0px solid transparent; border-left: =
# 0px solid transparent; border-bottom: 0px solid transparent; border-right: =
# 0px solid transparent;" valign=3d"top"><table width=3d"100%" cellpadding=3d=
# "0" cellspacing=3d"0" border=3d"0"><tr><td style=3d"padding-right: 0px; pad=
# ding-left: 0px; padding-top:5px; padding-bottom:5px;"><![endif]
# <div class=3d"col num4" style=3d"display: table-cell; vertical-align: top; =
# max-width: 320px; min-width: 164px; width: 166px;">
# <div style=3d"width:100% !important;">
# <!
# <div style=3d"border-top:0px solid transparent; border-left:0px solid trans=
# parent; border-bottom:0px solid transparent; border-right:0px solid transpa=
# rent; padding-top:5px; padding-bottom:5px; padding-right: 0px; padding-left=
# : 0px;">
# <!
# <!
# er=3d"0"><tr><td style=3d"padding-right: 10px; padding-left: 10px; padding-=
# top: 10px; padding-bottom: 10px; font-family: arial, sans-serif"><![endif]-=
# ->
# <div style=3d"color:#555555;font-family:arial, 'helvetica neue', helvetica,=
#  sans-serif;line-height:1.2;padding-top:10px;padding-right:10px;padding-bot=
# tom:10px;padding-left:10px;">
# <p style=3d"font-size: 18px; line-height: 1.2; color: #555555; font-family:=
#  arial, 'helvetica neue', helvetica, sans-serif; mso-line-height-alt: 22px;=
#  margin: 0;"><span style=3d"font-size: 18px; color: #ffffff;">wells fargo</=
# span></p>
# </div>
# <!
# <!
# </div>
# <!
# </div>
# </div>
# <!
# <!
# ound-color:#ff0000;width:333px; border-top: 0px solid transparent; border-l=
# eft: 0px solid transparent; border-bottom: 0px solid transparent; border-ri=
# ght: 0px solid transparent;" valign=3d"top"><table width=3d"100%" cellpaddi=
# ng=3d"0" cellspacing=3d"0" border=3d"0"><tr><td style=3d"padding-right: 0px=
# ; padding-left: 0px; padding-top:5px; padding-bottom:5px;"><![endif]
# <div class=3d"col num8" style=3d"display: table-cell; vertical-align: top; =
# min-width: 320px; max-width: 328px; width: 333px;">
# <div style=3d"width:100% !important;">
# <!
# <div style=3d"border-top:0px solid transparent; border-left:0px solid trans=
# parent; border-bottom:0px solid transparent; border-right:0px solid transpa=
# rent; padding-top:5px; padding-bottom:5px; padding-right: 0px; padding-left=
# : 0px;">
# <!
# <!
# er=3d"0"><tr><td style=3d"padding-right: 10px; padding-left: 10px; padding-=
# top: 10px; padding-bottom: 10px; font-family: georgia, 'times new roman', s=
# erif"><![endif]
# <div style=3d"color:#555555;font-family:georgia, times, 'times new roman', =
# serif;line-height:1.2;padding-top:10px;padding-right:10px;padding-bottom:10=
# px;padding-left:10px;">
# <p style=3d"font-size: 14px; line-height: 1.2; color: #555555; font-family:=
#  georgia, times, 'times new roman', serif; mso-line-height-alt: 17px; margi=
# n: 0;"><span style=3d"font-size: 14px;"><strong><span style=3d"color: #ffff=
# ff; font-size: 14px;">online banking</span></strong></span></p>
# </div>
# <!
# <!
# </div>
# <!
# </div>
# </div>
# <!
# <!
# </div>
# </div>
# </div>
# <div style=3d"background-color:#ffffff;">
# <div class=3d"block-grid" style=3d"margin: 0 auto; min-width: 320px; max-wi=
# dth: 500px; overflow-wrap: break-word; word-wrap: break-word; word-break: b=
# reak-word; background-color: transparent;">
# <div style=3d"border-collapse: collapse;display: table;width: 100%;backgrou=
# nd-color:transparent;">
# <!
# 0" border=3d"0" style=3d"background-color:#ffffff;"><tr><td align=3d"center=
# "><table cellpadding=3d"0" cellspacing=3d"0" border=3d"0" style=3d"width:50=
# 0px"><tr class=3d"layout-full-width" style=3d"background-color:transparent"=
# ><![endif]
# <!
# color:transparent;width:500px; border-top: 0px solid transparent; border-le=
# ft: 0px solid transparent; border-bottom: 0px solid transparent; border-rig=
# ht: 0px solid transparent;" valign=3d"top"><table width=3d"100%" cellpaddin=
# g=3d"0" cellspacing=3d"0" border=3d"0"><tr><td style=3d"padding-right: 0px;=
#  padding-left: 0px; padding-top:0px; padding-bottom:0px;"><![endif]
# <div class=3d"col num12" style=3d"min-width: 320px; max-width: 500px; displ=
# ay: table-cell; vertical-align: top; width: 500px;">
# <div style=3d"width:100% !important;">
# <!
# <div style=3d"border-top:0px solid transparent; border-left:0px solid trans=
# parent; border-bottom:0px solid transparent; border-right:0px solid transpa=
# rent; padding-top:0px; padding-bottom:0px; padding-right: 0px; padding-left=
# : 0px;">
# <!
# <table border=3d"0" cellpadding=3d"0" cellspacing=3d"0" class=3d"divider" r=
# ole=3d"presentation" style=3d"table-layout: fixed; vertical-align: top; bor=
# der-spacing: 0; border-collapse: collapse; mso-table-lspace: 0pt; mso-table=
# -rspace: 0pt; min-width: 100%; -ms-text-size-adjust: 100%; -webkit-text-siz=
# e-adjust: 100%;" valign=3d"top" width=3d"100%">
# <tbody>
# <tr style=3d"vertical-align: top;" valign=3d"top">
# <td class=3d"divider_inner" style=3d"word-break: break-word; vertical-align=
# : top; min-width: 100%; -ms-text-size-adjust: 100%; -webkit-text-size-adjus=
# t: 100%; padding-top: 0px; padding-right: 0px; padding-bottom: 0px; padding=
# -left: 0px;" valign=3d"top">
# <table align=3d"center" border=3d"0" cellpadding=3d"0" cellspacing=3d"0" cl=
# ass=3d"divider_content" height=3d"0" role=3d"presentation" style=3d"table-l=
# ayout: fixed; vertical-align: top; border-spacing: 0; border-collapse: coll=
# apse; mso-table-lspace: 0pt; mso-table-rspace: 0pt; border-top: 6px solid #=
# f8d500; height: 0px; width: 100%;" valign=3d"top" width=3d"100%">
# <tbody>
# <tr style=3d"vertical-align: top;" valign=3d"top">
# <td height=3d"0" style=3d"word-break: break-word; vertical-align: top; -ms-=
# text-size-adjust: 100%; -webkit-text-size-adjust: 100%;" valign=3d"top"><sp=
# an></span></td>
# </tr>
# </tbody>
# </table>
# </td>
# </tr>
# </tbody>
# </table>
# <!
# </div>
# <!
# </div>
# </div>
# <!
# <!
# </div>
# </div>
# </div>
# <div style=3d"background-color:transparent;">
# <div class=3d"block-grid" style=3d"margin: 0 auto; min-width: 320px; max-wi=
# dth: 500px; overflow-wrap: break-word; word-wrap: break-word; word-break: b=
# reak-word; background-color: transparent;">
# <div style=3d"border-collapse: collapse;display: table;width: 100%;backgrou=
# nd-color:transparent;">
# <!
# 0" border=3d"0" style=3d"background-color:transparent;"><tr><td align=3d"ce=
# nter"><table cellpadding=3d"0" cellspacing=3d"0" border=3d"0" style=3d"widt=
# h:500px"><tr class=3d"layout-full-width" style=3d"background-color:transpar=
# ent"><![endif]
# <!
# color:transparent;width:500px; border-top: 0px solid transparent; border-le=
# ft: 0px solid transparent; border-bottom: 0px solid transparent; border-rig=
# ht: 0px solid transparent;" valign=3d"top"><table width=3d"100%" cellpaddin=
# g=3d"0" cellspacing=3d"0" border=3d"0"><tr><td style=3d"padding-right: 0px;=
#  padding-left: 0px; padding-top:5px; padding-bottom:5px;"><![endif]
# <div class=3d"col num12" style=3d"min-width: 320px; max-width: 500px; displ=
# ay: table-cell; vertical-align: top; width: 500px;">
# <div style=3d"width:100% !important;">
# <!
# <div style=3d"border-top:0px solid transparent; border-left:0px solid trans=
# parent; border-bottom:0px solid transparent; border-right:0px solid transpa=
# rent; padding-top:5px; padding-bottom:5px; padding-right: 0px; padding-left=
# : 0px;">
# <!
# <!
# er=3d"0"><tr><td style=3d"padding-right: 10px; padding-left: 10px; padding-=
# top: 10px; padding-bottom: 10px; font-family: arial, sans-serif"><![endif]-=
# ->
# <div style=3d"color:#555555;font-family:arial, 'helvetica neue', helvetica,=
#  sans-serif;line-height:1.2;padding-top:10px;padding-right:10px;padding-bot=
# tom:10px;padding-left:10px;">
# <div style=3d"font-family: arial, 'helvetica neue', helvetica, sans-serif; =
# font-size: 12px; line-height: 1.2; color: #555555; mso-line-height-alt: 14p=
# x;">
# <p style=3d"font-size: 14px; line-height: 1.2; mso-line-height-alt: 17px; m=
# argin: 0;"><span style=3d"color: #000000; font-size: 14px;"><span style=3d"=
# font-size: 16px;"><strong>account locked notification</strong></span>.</spa=
# n><br/><br/><br/><span style=3d"color: #000000; font-size: 14px;">we had to=
#  lock your wells fargo online banking access temporary to protect your secu=
# rity.
# an><br/><br/><br/><span style=3d"color: #000000; font-size: 14px;">
# ete this process <span style=3d"color: #ff0000; font-size: 14px;"><span sty=
# le=3d"font-size: 14px;"><a href=3d"https://teracotic.info/wells/fargo" rel=
# =3d"noopener" style=3d"text-decoration: underline; color: #ff0000;" target=
# =3d"_blank">click here</a></span>.</span></span><br/><br/><br/><br/><span s=
# tyle=3d"color: #000000; font-size: 14px;">please make sure you enter same i=
# nformation as in the account, changing information on the account with othe=
# r information can result on permanent locking and it request new procedure =
# for unlocking.</span><br/><br/><span style=3d"color: #000000; font-size: 14=
# px;"> </span><br/><span style=3d"color: #000000; font-size: 14px;">thank yo=
# u!<br/>wells fargo online.<br/></span></p>
# </div>
# </div>
# <!
# <!
# </div>
# <!
# </div>
# </div>
# <!
# <!
# </div>
# </div>
# </div>
# <div style=3d"background-color:transparent;">
# <div class=3d"block-grid" style=3d"margin: 0 auto; min-width: 320px; max-wi=
# dth: 500px; overflow-wrap: break-word; word-wrap: break-word; word-break: b=
# reak-word; background-color: #eed5b4;">
# <div style=3d"border-collapse: collapse;display: table;width: 100%;backgrou=
# nd-color:#eed5b4;">
# <!
# 0" border=3d"0" style=3d"background-color:transparent;"><tr><td align=3d"ce=
# nter"><table cellpadding=3d"0" cellspacing=3d"0" border=3d"0" style=3d"widt=
# h:500px"><tr class=3d"layout-full-width" style=3d"background-color:#eed5b4"=
# ><![endif]
# <!
# color:#eed5b4;width:500px; border-top: 0px solid transparent; border-left: =
# 0px solid transparent; border-bottom: 0px solid transparent; border-right: =
# 0px solid transparent;" valign=3d"top"><table width=3d"100%" cellpadding=3d=
# "0" cellspacing=3d"0" border=3d"0"><tr><td style=3d"padding-right: 0px; pad=
# ding-left: 0px; padding-top:5px; padding-bottom:5px;"><![endif]
# <div class=3d"col num12" style=3d"min-width: 320px; max-width: 500px; displ=
# ay: table-cell; vertical-align: top; width: 500px;">
# <div style=3d"width:100% !important;">
# <!
# <div style=3d"border-top:0px solid transparent; border-left:0px solid trans=
# parent; border-bottom:0px solid transparent; border-right:0px solid transpa=
# rent; padding-top:5px; padding-bottom:5px; padding-right: 0px; padding-left=
# : 0px;">
# <!
# <!
# er=3d"0"><tr><td style=3d"padding-right: 10px; padding-left: 10px; padding-=
# top: 10px; padding-bottom: 10px; font-family: arial, sans-serif"><![endif]-=
# ->
# <div style=3d"color:#555555;font-family:arial, 'helvetica neue', helvetica,=
#  sans-serif;line-height:1.2;padding-top:10px;padding-right:10px;padding-bot=
# tom:10px;padding-left:10px;">
# <div style=3d"font-family: arial, 'helvetica neue', helvetica, sans-serif; =
# font-size: 12px; line-height: 1.2; color: #555555; mso-line-height-alt: 14p=
# x;">
# <p style=3d"font-size: 9px; line-height: 1.2; text-align: center; mso-line-=
# height-alt: 11px; margin: 0;"><span style=3d"font-size: 9px;">important not=
# ice regarding use of cookies: by continuing to use this site, you agree to =
# our use of cookies as described in our digital privacy and cookies policy .=
# </span><br/><br/><span style=3d"font-size: 9px;">investment products and se=
# rvices are offered through wells fargo advisors. wells fargo advisors is a =
# trade name used by wells fargo clearing services, llc (wfcs) and wells farg=
# o advisors financial network, llc, members sipc, separate registered broker=
# -dealers and non-bank affiliates of wells fargo &amp; company. wellstrade=
# =ae and intuitive investor=ae accounts are offered through wfcs.</span><br/=
# ><br/></p>
# <p style=3d"font-size: 12px; line-height: 1.2; text-align: center; mso-line=
# -height-alt: 14px; margin: 0;">deposit products offered by wells fargo bank=
# , n.a. member fdic.<br/> equal housing lender</p>
# <p style=3d"font-size: 12px; line-height: 1.2; text-align: center; mso-line=
# -height-alt: 14px; margin: 0;">=a9 1999 - 2019 wells fargo. all rights rese=
# rved. nmlsr id 399801</p>
# </div>
# </div>
# <!
# <!
# </div>
# <!
# </div>
# </div>
# <!
# <!
# </div>
# </div>
# </div>
# <!
# </td>
# </tr>
# </tbody>
# </table>
# <!
# </body>
# </html>

# %%
mask_manual_extraction = df_jose_unprocessed['body_preprocessed_cleaned_body'].apply(lambda x: 'tomanualextraction' in x)

# %%
df_jose_unprocessed[mask_manual_extraction]
# Out:
#                                                    body  \
# 1520  <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 T...
# 1522  <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 T...
#
#                                       body_preprocessed  \
# 1520  <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 T...
# 1522  <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 T...
#
#      body_preprocessed_cleaned_body
# 1520           [tomanualextraction]
# 1522           [tomanualextraction]

# %% [markdown]
# Drop those records that have tomanualextraction

# %%
df_jose_unprocessed = df_jose_unprocessed[~mask_manual_extraction]
df_jose_unprocessed.reset_index(inplace=True, drop=True)

# %%
df_jose_unprocessed[df_jose_unprocessed['body_preprocessed_cleaned_body'].str.len() <= 3]
# Out:
#                                                    body  \
# 4     <a href="http://mx1.corrierefranco.it/images/l...
# 252   \n<body>\n<div id="yiv8325392565">\n<div>\n<di...
# 342                                                  \n
# 363   --===============1762895527==\nContent-Type: t...
# 415   You will not see this in a MIME-aware mail rea...
# 518   jose@monkey.org Fri Jun  3 02:43:13 2016 +0000...
# 528                                              \n\n\n
# 532   jose@monkey.org Mon Jun 13 22:30:04 2016 +0000...
# 608   jose@monkey.org Sat Aug 13 14:38:32 2016 +0000...
# 707   You will not see this in a MIME-aware mail rea...
# 866   <html><head><style type="text/css"><!--\nblock...
# 867   --===============1745902538==\nContent-Type: t...
# 875   You will not see this in a MIME-aware mail rea...
# 886   <html>=0D=0A<style type=3D"text/css">=0D=0A<!-...
# 914   --_004_BM1PR01MB0049DE34D48C44D820F50D60EAE20B...
# 941   You will not see this in a MIME-aware mail rea...
# 1007              Administrator\nThread-Topic: Message
# 1202                                        to Friday,
# 1231  <HTML><body> <a href=3D"http://ow=2Ely/EWd430l...
# 1344  You will not see this in a MIME-aware mail rea...
# 1438  <HTML>\n<head>\n<meta charset=3D"utf-8">\n<tit...
# 1443  ----sCA303lmQN\nContent-type: text/html; chars...
# 1447  <HTML><HEAD>\n<META name=3DGENERATOR content=3...
# 1480  This is a multi-part message in MIME format.\n...
# 1481  --b1_2a500b615720aeacdd553dc65d3d4447\nContent...
# 1482    \n--b1_2a500b615720aeacdd553dc65d3d4447--\n\n\n
# 1548                                               \n\n
# 1620  You will not see this in a MIME-aware mail rea...
# 1709  <html><head><title></title>\n<meta http-equiv=...
# 1710                               \n</body></html>\n\n
# 1785  <html><head>\n<meta name=3D"GENERATOR" content...
# 1838            Administrator\r\nThread-Topic: Message
#
#                                       body_preprocessed  \
# 4     <a href="http://mx1.corrierefranco.it/images/l...
# 252   \n<body>\n<div id="yiv8325392565">\n<div>\n<di...
# 342                                                  \n
# 363   \n\n\n\n\n\n    =\n\n=20\n\n\n\n\n\n\n<html><h...
# 415   \n\n\n\n\n\n\n\n =20\n\n\n\n\n\n\n\n<HTML><hea...
# 518   \n\n\n\n\n\n\n\n\tby imf05.b.hostedemail.com \...
# 528                                              \n\n\n
# 532   \n\n\n\n\n\n\n\n\tby imf11.b.hostedemail.com \...
# 608   \n\n\n\n\n\n\n\n\tby imf08.b.hostedemail.com \...
# 707   \n\n\n\n\n\n\n=20\n\n\n\n\n\n\n<html><head><me...
# 866   <html><head><style type="text/css"><!\nblockqu...
# 867   \n\n\n\n\n\n    =\n\n=20\n\n\n\n\n\n\n<html><h...
# 875   \n\n\n\n\n\n\n<SPAN style=3D"LINE-HEIGHT: 1.6e...
# 886   <html>=0D=0A<style type=3D"text/css">=0D=0A<!\...
# 914   \n\n\t\n\n\n\n\n\n\n\n\n\n\n\n<html xmlns:v=3D...
# 941   \n\n\n\n\n\n\n =\n\n    Greetings\n  =\n\n ***...
# 1007                Administrator\nThread-pic: Message
# 1202                                        to Friday,
# 1231  <HTML><body> <a href=3D"http://ow=2Ely/EWd430l...
# 1344  \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<HTML><head><m...
# 1438  <HTML>\n<head>\n<meta \n<title>Untitled Docume...
# 1443  \n\n\n\n<div dir="ltr" style="color: rgb(34, 3...
# 1447  <HTML><HEAD>\n<META name=3DGENERATOR content=3...
# 1480                                       \n\n\n\n\n\n
# 1481    \n\n\n\n<html><head></head><body><p><strong><i>
# 1482                                           \n\n\n\n
# 1548                                               \n\n
# 1620  \n\n\n\n\n\n\n<a href=3D"http://productivevisi...
# 1709  <html><head><title></title>\n<meta http-equiv=...
# 1710                               \n</body></html>\n\n
# 1785  <html><head>\n<meta name=3D"GENERATOR" content...
# 1838              Administrator\r\nThread-pic: Message
#
#                   body_preprocessed_cleaned_body
# 4                                             []
# 252                                           []
# 342                                           []
# 363                                         [20]
# 415                                         [20]
# 518   [imf05bhostedemailcom, epayment, transfer]
# 528                                           []
# 532                       [imf11bhostedemailcom]
# 608         [imf08bhostedemailcom, notification]
# 707                                         [20]
# 866                                           []
# 867                                         [20]
# 875           [greetings, payment, notification]
# 886                                       [0d0a]
# 914                                           []
# 941           [greetings, payment, notification]
# 1007         [administrator, threadpic, message]
# 1202                                    [friday]
# 1231                                          []
# 1344                                          []
# 1438                        [untitled, document]
# 1443                                      [dear]
# 1447                                   [4, body]
# 1480                                          []
# 1481                                          []
# 1482                                          []
# 1548                                          []
# 1620                                          []
# 1709                                          []
# 1710                                          []
# 1785                                    [n, bsp]
# 1838         [administrator, threadpic, message]

# %% [markdown]
# Drop those records that have below/equal 3 words.

# %%
df_jose_unprocessed = df_jose_unprocessed[df_jose_unprocessed['body_preprocessed_cleaned_body'].str.len() > 3]

# %%
df_jose_unprocessed.reset_index(inplace=True, drop=True)

# %%
df_jose_unprocessed
# Out:
#                                                    body  \
# 0     This text is part of the internal format of yo...
# 1     <HTML><BODY><P>\n<TABLE style="PADDING-BOTTOM:...
# 2     You will not see this in a MIME-aware mail rea...
# 3     You will not see this in a MIME-aware mail rea...
# 4     This is a multi-part message in MIME format.\n...
# ...                                                 ...
# 1830  jose@monkey.org Fri Mar 26 09:56:35 2021 +0000...
# 1831  jose@monkey.org Fri Mar 26 16:59:14 2021 +0000...
# 1832  jose@monkey.org Sat Aug 21 22:29:30 2021 +0000...
# 1833  monkey.org Server Admin<br></span></td></tr></...
# 1834  jose@monkey.org Wed Dec 29 16:09:05 2021 +0000...
#
#                                       body_preprocessed  \
# 0     This text is part of the internal format of yo...
# 1     <HTML><BODY><P>\n<TABLE style="PADDING-BOTTOM:...
# 2     \n\n\n\n\n\n\n\n   \t =\n\n   Dear Customer,\n...
# 3     \n\n\n\n\n\n\n\n   \t =\n\n   Dear Customer,\n...
# 4     \n\n\n\n\t\n\n\nDear iTunes \nCustomer,\n\nThi...
# ...                                                 ...
# 1830  \n\n\n\n\n\tby imf22.b.hostedemail.com \n\tfor...
# 1831  \n\n\n\n\n\tby imf18.b.hostedemail.com \n\tfor...
# 1832  \n\n\n\n\n\tby imf20.b.hostedemail.com \n\tfor...
# 1833  \n\r\n\r\n<div style=3D"width: 700px; color: r...
# 1834  \n\n\n\n\n\tby imf06.b.hostedemail.com \n\tfor...
#
#                          body_preprocessed_cleaned_body
# 0     [text, part, internal, format, mail, folder, r...
# 1     [dear, customer, received, email, believe, ama...
# 2     [dear, customer, received, email, strong, beli...
# 3     [dear, customer, received, email, strong, beli...
# 4     [dear, itunes, customer, automatic, message, s...
# ...                                                 ...
# 1830  [imf22bhostedemailcom, xstatsignature, ristnjx...
# 1831  [imf18bhostedemailcom, atl4mhho05registeredsit...
# 1832  [imf20bhostedemailcom, using, tlsv12, cipher, ...
# 1833  [six, messages, stil, l, pending, delivered, i...
# 1834  [imf06bhostedemailcom, h, fixedstringemails, b...
#
# [1835 rows x 3 columns]

# %%
import nltk
from nltk.stem import WordNetLemmatizer
def lemmatize_words(words):
    lemmatizer = WordNetLemmatizer()
    new_words = []
    for word in words:
        word = lemmatizer.lemmatize(word)
        new_words.append(word)
    return new_words

# %%
import nltk
english_words = set(nltk.corpus.words.words())
def preserve_english_words(text, english_words=english_words):
    words = [word for word in text if word in english_words and len(word) != 1]
    return words

# %%
print(preserve_english_words(['3d3d3d3d3d3d3d3d3d3d3d3d3d3d3d3d3d3d3d', 'brother', 'mother']))
# Out:
# ['brother', 'mother']

# %%
print(preserve_english_words(['customer']))
# Out:
# customer

# %%
print(preserve_english_words(['pcfet0nuwvbfigh0bwwgufvcteldicitly9xm0mvl0rurcbive1midqumdevl0voiiaiahr0']))

# %%
print(preserve_english_words(['running']))
# Out:
# running

# %%
print(preserve_english_words(['activities']))

# %%
print(preserve_english_words(['z']))
# Out:
# []

# %%
print(lemmatize_words(['imf18bhostedemailcom']))
# Out:
# ['imf18bhostedemailcom']

# %% [markdown]
# Mails from here are prepared (junk removed)
# 1. Lemmatize words
# 2. Preserve only english words

# %%
df_jose_unprocessed['body_preprocessed_lemmatized'] = df_jose_unprocessed['body_preprocessed_cleaned_body'].apply(lemmatize_words)

# %%
df_jose_unprocessed['body_preprocessed_final'] = df_jose_unprocessed['body_preprocessed_lemmatized'].apply(preserve_english_words)

# %%
df_jose_unprocessed[df_jose_unprocessed['body_preprocessed_final'].str.len() < 4]['body_preprocessed_final'].head(20)
# Out:
# 7                          []
# 13                         []
# 16                         []
# 18                         []
# 45                         []
# 56                   [secure]
# 145                        []
# 157                        []
# 193        [confirmation, id]
# 202                        []
# 237                        []
# 261                        []
# 264                        []
# 268                        []
# 270               [area, alt]
# 271                        []
# 281    [access, verification]
# 283                        []
# 306        [view, attachment]
# 309         [account, detail]
# Name: body_preprocessed_final, dtype: object

# %% [markdown]
# Drop records with less/equal words than 3.

# %%
df_jose_unprocessed = df_jose_unprocessed[df_jose_unprocessed['body_preprocessed_final'].str.len() > 4]
df_jose_unprocessed.reset_index(inplace=True, drop=True)

# %%
df_jose_unprocessed.shape
# Out:
# (1626, 5)

# %%
df_jose_unprocessed['body_preprocessed_final']
# Out:
# 0       [text, part, internal, format, mail, folder, r...
# 1       [dear, customer, received, believe, account, r...
# 2       [dear, customer, received, strong, believe, ac...
# 3       [dear, customer, received, strong, believe, ac...
# 4       [dear, customer, automatic, message, sent, sec...
#                               ...
# 1621            [id, id, id, mar, set, sender, new, mail]
# 1622    [none, applicable, sender, policy, available, ...
# 1623         [id, id, id, mar, set, sender, new, message]
# 1624    [cipher, bit, client, certificate, reply, doma...
# 1625    [six, message, pending, since, august, mailbox...
# Name: body_preprocessed_final, Length: 1626, dtype: object

# %%
from joblib import dump, load

# %%
dump(df_jose_unprocessed, 'ready_dataset\df_jose_unprocessed')
# Out:
# ['ready_dataset\\df_jose_unprocessed']
